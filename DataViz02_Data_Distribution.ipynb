# %% [markdown]
# <a href="https://colab.research.google.com/github/sskboonmee/data_viz_2022/blob/main/DataViz02_Data_Distribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Data

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# # Scatter Plot
# การ Plot จุดลงไปในแกน X,Y

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter([1,-1],[2,-1]) #จุดแรก X=1 Y=2 อีกจุดนึง X=-1 Y=-1

# %%
plt.scatter(df['PetalLength'],df['SepalLength'])

# %% [markdown]
# ##เปลี่ยนสี

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],c='r')

# %% [markdown]
# ###ระบุสีให้แต่ละจุด

# %%
set(df['Name'])
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %% [markdown]
# ###แทนค่าที่ดอกไม้ด้วยตัวอักษรแทนสี (r g b c m y k w )

# %%
df2 = df.replace({'Iris-setosa':'r', 'Iris-versicolor':'g' ,'Iris-virginica':'b'})

# %%
df2.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth Name
# 0          5.1         3.5          1.4         0.2    r
# 1          4.9         3.0          1.4         0.2    r
# 2          4.7         3.2          1.3         0.2    r
# 3          4.6         3.1          1.5         0.2    r
# 4          5.0         3.6          1.4         0.2    r

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])

# %% [markdown]
# ##เพิ่มรายละเอียดกราฟ

# %% [markdown]
# ### ชื่อแกน

# %%
plt.scatter(df2['PetalLength'],df2['SepalLength'],c=df2['Name'])
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
# Out:
# Text(0, 0.5, 'SepalLength')

# %% [markdown]
# ### ชื่อ maker

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga')
plt.legend() #legend=ตัวอธบาย maker
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## ใช้ขนาดของ maker ในการแสดงค่าใน column

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=df2['PetalWidth'][100:])
plt.legend() #legend=ตัวอธบาย maker
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ###ขยายขนาด maker ที่เล็กเกินไป

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],c=df2['Name'][:50],label='setosa',s=20*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],c=df2['Name'][50:100],label='versicolor',s=20*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],c=df2['Name'][100:],label='verginiga',s=20*df2['PetalWidth'][100:])
plt.legend() #legend=ตัวอธบาย maker
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');  #จากกราฟ setosa เล็กสุด

# %% [markdown]
# ## ปรับความโปร่งใสของ maker เพื่อให้มองเห็นจุดที่ถูกบัง

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=20*df2['PetalWidth'][:50])
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=20*df2['PetalWidth'][50:100])
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=20*df2['PetalWidth'][100:])
plt.legend() #legend=ตัวอธบาย maker
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ## เปลี่ยน หน้าตาของ Maker เพื่อความสวยงาม

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='X')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='X')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='X')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %%
plt.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],alpha=0.5,c=df2['Name'][:50],label='setosa',s=40*df2['PetalWidth'][:50],marker='$s$')
plt.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],alpha=0.5,c=df2['Name'][50:100],label='versicolor',s=40*df2['PetalWidth'][50:100],marker='$c$')
plt.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],alpha=0.5,c=df2['Name'][100:],label='verginiga',s=40*df2['PetalWidth'][100:],marker='$g$')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ##แสดงแบบ 3 มิติ

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'],df2['SepalLength'],df2['SepalWidth'],c=df2['Name'],s=80*df2['PetalWidth'])

# %%
ax = plt.axes(projection = "3d")
ax.scatter(df2['PetalLength'][:50],df2['SepalLength'][:50],df2['SepalWidth'][:50],c=df2['Name'][:50],s=80*df2['PetalWidth'][:50],label='setosa')
ax.scatter(df2['PetalLength'][50:100],df2['SepalLength'][50:100],df2['SepalWidth'][50:100],c=df2['Name'][50:100],s=80*df2['PetalWidth'][50:100],label='versicolor')
ax.scatter(df2['PetalLength'][100:],df2['SepalLength'][100:],df2['SepalWidth'][100:],c=df2['Name'][100:],s=80*df2['PetalWidth'][100:],label='verginica')
plt.legend()
plt.xlabel('PetalLength')
plt.ylabel('SepalLength')
plt.title('comparing petal&sepal length of different iris flowers');

# %% [markdown]
# ##Boxplot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from matplotlib import pyplot as plt

# %%
plt.boxplot(df['SepalLength'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69cf7df2d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69cf7e6150>,
#   <matplotlib.lines.Line2D at 0x7f69cf7e6690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69cf7e6bd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69cf7e6e10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69cf7df650>,
#   <matplotlib.lines.Line2D at 0x7f69cf7dfbd0>]}

# %%
plt.boxplot(df['SepalLength'],vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69cf74fc90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69cf754b10>,
#   <matplotlib.lines.Line2D at 0x7f69cf754ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69cf75a590>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69cf75a810>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69cf741210>,
#   <matplotlib.lines.Line2D at 0x7f69cf7545d0>]}

# %%
ybp = plt.boxplot(df['SepalLength'],vert=False)

# %% [markdown]
# median

# %%
ybp['medians'][0].get_ydata()
# Out:
# array([0.925, 1.075])

# %%
ybp['medians'][0].get_xdata()
# Out:
# array([5.8, 5.8])

# %%
ybp['whiskers'][0].get_xdata()
# Out:
# array([5.1, 4.3])

# %% [markdown]
# min

# %%
min(ybp['whiskers'][0].get_xdata())
# Out:
# 4.3

# %% [markdown]
# mix

# %%
max(ybp['whiskers'][1].get_xdata())
# Out:
# 7.9

# %%
(ybp['caps'][1].get_xdata())
# Out:
# array([7.9, 7.9])

# %% [markdown]
# q1

# %%
ybp['boxes'][0].get_xdata()[0]
# Out:
# 5.1

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69cf6409d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69cf645850>,
#   <matplotlib.lines.Line2D at 0x7f69cf645d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69cf64d890>],
#  'means': [<matplotlib.lines.Line2D at 0x7f69cf64dad0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69cf64d550>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69cf640d50>,
#   <matplotlib.lines.Line2D at 0x7f69cf645310>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,meanline=True,showmeans=True)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69d10879d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69d100e550>,
#   <matplotlib.lines.Line2D at 0x7f69d1083c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69d106b450>],
#  'means': [<matplotlib.lines.Line2D at 0x7f69cf7867d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69cf786810>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69d1029510>,
#   <matplotlib.lines.Line2D at 0x7f69d107afd0>]}

# %%
plt.boxplot(df['SepalLength'],vert=False,showmeans=True,meanprops={'marker':'o'})
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69d312e7d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69d30f8ed0>,
#   <matplotlib.lines.Line2D at 0x7f69d30f8210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69d3275290>],
#  'means': [<matplotlib.lines.Line2D at 0x7f69d318fc90>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69d32757d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69d312eb10>,
#   <matplotlib.lines.Line2D at 0x7f69d30f8550>]}

# %% [markdown]
# Quiz กลุ่ม final
#
#
# 1.  เขียน function เป็น output ของ boxplot แล้วแสดงค่า min, max,q1,q2,q3
# 2.  วาด boxplot เปรียบเทียบการกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3

# %% [markdown]
# 1.เขียน function เป็น output ของ boxplot แล้วแสดงค่า min, max,q1,q2,q3

# %%
def box_vals(box_out_dict, vert = True):
    if vert == True:
        Q1 = box_out_dict['boxes'][0].get_ydata()[0]
        Q2 = box_out_dict['medians'][0].get_ydata()[0]
        Q3 = box_out_dict['boxes'][0].get_ydata()[2]
        vmin = box_out_dict['caps'][0].get_ydata()[0]
        vmax = box_out_dict['caps'][1].get_ydata()[0]
    return Q1,Q2,Q3,vmin,vmax

# %%
quiz = plt.boxplot(df['PetalLength'],vert=False)

# %%
box_vals(quiz)
# Out:
# (0.925, 0.925, 1.075, 0.9625, 0.9625)

# %% [markdown]
# 2.วาด boxplot เปรียบเทียบการกระจายตัวของข้อมูล PetalLength ของดอก iris ทั้ง 3

# %%
plt.boxplot(df['PetalLength'][:50],vert=False) #setsosa
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69d358eb10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69d3477b50>,
#   <matplotlib.lines.Line2D at 0x7f69d3480c90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69d3368cd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69d3368110>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69d3a49f90>,
#   <matplotlib.lines.Line2D at 0x7f69d3a773d0>]}

# %%
plt.boxplot(df['PetalLength'][50:100],vert=False)  #versicolor
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69d32c6510>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69d3b16b50>,
#   <matplotlib.lines.Line2D at 0x7f69d3ab10d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69d34b2250>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69d34b2b10>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69d32c6810>,
#   <matplotlib.lines.Line2D at 0x7f69d35b4790>]}

# %%
plt.boxplot(df['PetalLength'][100:],vert=False)  #verginiga
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f69d33c1450>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f69d33c8290>,
#   <matplotlib.lines.Line2D at 0x7f69d33c87d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f69d33c8d10>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f69d33c8f50>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f69d33c17d0>,
#   <matplotlib.lines.Line2D at 0x7f69d33c1d10>]}
