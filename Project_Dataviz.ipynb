# %% [markdown]
# <a href="https://colab.research.google.com/github/sskboonmee/data_viz_2022/blob/main/Project_Dataviz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project ทำ Dashboard ของ Data Covid (ตั้งแต่วันที่ 12/01/2020 - 18/03/2022) เล่ามุมมองที่เราเลือกเอง + ใช้ข้อมูลภูมิภาค + ข้อมูลอื่นที่เลือกเอง ซึ่งข้อมูลที่เลือกเองคือ  ข้อมูลผู้ป่วยระลอก 1 ถึงระลอก 2 (ตั้งแต่ 12/01/2020 – 31/03/2021)

# %% [markdown]
# #รายชื่อสมาชิกในกลุ่ม
#
# ชื่อกลุ่ม : สามสาว
#
# นางสาวศศิกานต์ บุญมี รหัสนักศึกษา 623020539-9
# นางสาวอุมาพร คำภิชัย รหัสนักศึกษา 623020547-0
# นางสาวอาทิตยา แสงนิลเกิด รหัสนักศึกษา 623021010-8

# %% [markdown]
# ที่มาของแหล่งข้อมูลทั้ง 3 แหล่ง
# * ข้อมูลชุดที่ 1 DATA COVID : https://data.go.th/
# * ข้อมูลชุดที่ 2 ข้อมูลที่สนใจ --> ข้อมูลสถิติการรับรองและสถานะการรับรองของสถานพยาบาลตามมาตรฐาน HA ขั้น 1-3 และ Advanced-HA : https://data.go.th/dataset/04_0101-ha-1-3-advanced-ha?fbclid=IwAR0GfPjiBB-Xqy6bOjlfKNHG
# * ข้อมูลชุดที่ 3 ข้อมูลภูมิภาค : https://th.wikipedia.org/

# %% [markdown]
# #นำข้อมูลเข้า

# %%
import pandas as pd #import panda เพื่อจัดการตารางเล็กน้อย

# %%
from google.colab import drive
drive.mount('/content/drive')  #เป็นการนำข้อมูลเพิ่มเข้าไปที่colab
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os 
path = '/content/drive/My Drive/DATA_Final_Project' #เชื่อมกับไดร์ฟ

# %%
data_file_path = os.path.join(path,'DATACOVID_1.csv')    #ชี้ที่อยู่ในไฟล์
data_1 = pd.read_csv(data_file_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# #ข้อมูลชุดที่ 1 Data Covid

# %% [markdown]
# ##Data Covid วันที่ 12/01/2020 - 12/08/2021

# %%
data_1 ##แสดงข้อมูลชุดที่ 1 ออกมาเป็นตาราง จะเห็นว่ามีค่า missing
# Out:
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# 839769  839770     12/8/2021     11/8/2021   ชาย  83.0   ปี    Thailand
# 839770  839771     12/8/2021     11/8/2021   ชาย  47.0   ปี    Thailand
#
#        province_of_isolation                              risk  \
# ...

# %%
data_1.isnull().any() ##ตรวจสอบดูว่ามีค่า missing มั้ย
# Out:
# No.                      False
# announce_date            False
# Notified date             True
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_1_drop = data_1.dropna()  ##กำจัดค่า missing โดนใช้ .dropna()
data_1_drop #แสดงค่า จะเห็นว่าค่า missing หายไปแล้ว
# Out:
#            No. announce_date Notified date   sex   age Unit     nationality  \
# 47          48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 124        125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 161        162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 181        182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 186        187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...        ...           ...           ...   ...   ...  ...             ...
# 839391  839392     12/8/2021     11/8/2021  หญิง  83.0   ปี        Thailand
# 839392  839393     12/8/2021     11/8/2021   ชาย  66.0   ปี        Thailand
# 839393  839394     12/8/2021     11/8/2021  หญิง  43.0   ปี        Thailand
# 839394  839395     12/8/2021     11/8/2021  หญิง  74.0   ปี        Thailand
# 839395  839396     12/8/2021     11/8/2021   ชาย  29.0   ปี        Thailand
#
#        province_of_isolation  \
# ...

# %%
data_1_drop.isnull().any()  #ไม่มีค่า missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ## ตารางที่ 2 Data Covid วันที่ 12/08/2021 - 25/10/2021

# %%
data_file_path = os.path.join(path,'DATACOVID_2.csv')     #แสดงค่า จะเห็นว่ามีค่า missing
data_2 = pd.read_csv(data_file_path)

# %%
data_2  #แสดงค่า จะเห็นว่ามีค่า missing
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %%
data_2.isnull().any() #จะเห็นว่ามีค่า missing
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                     False
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_2_drop = data_2.dropna() #กำจัดค่า missing โดนใช้ .dropna()
data_2_drop #แสดงค่า จะเห็นว่าค่า missing หายไปแล้ว
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 249       817239     12/8/2021     11/8/2021   ชาย  48.0   ปี    Thailand
# 250       817240     12/8/2021     11/8/2021  หญิง  19.0   ปี    Thailand
# 251       817241     12/8/2021     11/8/2021  หญิง  37.0   ปี    Thailand
# 252       817242     12/8/2021     11/8/2021   ชาย  46.0   ปี    Thailand
# 253       817243     12/8/2021     11/8/2021   ชาย  60.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1041962  1858952    25/10/2021    24/10/2021   ชาย  67.0   ปี    Thailand
# 1041963  1858953    25/10/2021    24/10/2021  หญิง  39.0   ปี    Thailand
# 1041964  1858954    25/10/2021    24/10/2021   ชาย  80.0   ปี    Thailand
# 1041965  1858955    25/10/2021    24/10/2021  หญิง  67.0   ปี    Thailand
# 1041966  1858956    25/10/2021    24/10/2021  หญิง  53.0   ปี    Thailand
#
#         province_of_isolation                                         risk  \
# ...

# %%
data_2_drop.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ## ตารางที่ 3 Data Covid วันที่ 26/10/2021 - 27/02/2022

# %%
data_file_path = os.path.join(path,'DATACOVID_3.csv')     #แสดงข้อมูลชุดที่ 3 ออกมาเป็นตาราง 
data_3 = pd.read_csv(data_file_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_3 #แสดงค่า จะเห็นว่ามีค่า missing
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# ...

# %% [markdown]
# ลบคอลัมน์ Unnamed: 11 ในตารางที่ 3

# %%
data_3n = data_3.drop('Unnamed: 11', axis=1) #axis=1 คือ คอลัมน์

# %%
data_3n   #แสดงข้อมูล จะเห็นว่ามีค่า missing
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010457  2869615     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010458  2869616     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
#
#         province_of_isolation                                           risk  \
# ...

# %%
data_3n.isnull().any()  #ดูว่ามีค่า missing มั้ย
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation     True
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_3n_drop = data_3n.dropna() #กำจัดค่า missing โดนใช้ .dropna()
data_3n_drop  #แสดงค่า จะเห็นว่าค่า missing หายไปแล้ว
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010370  2869528     27/2/2022     26/2/2022  หญิง   7.0   ปี    Thailand
# 1010371  2869529     27/2/2022     26/2/2022   ชาย  38.0   ปี      French
# 1010372  2869530     27/2/2022     26/2/2022  หญิง  58.0   ปี      French
# 1010373  2869531     27/2/2022     26/2/2022   ชาย  66.0   ปี    Thailand
# 1010374  2869532     27/2/2022     26/2/2022   ชาย  64.0   ปี    Thailand
#
#         province_of_isolation                                           risk  \
# ...

# %%
data_3n_drop.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ## ตารางที่ 4 Data Covid วันที่ 28/2/2022 - 15/3/2022

# %%
data_file_path = os.path.join(path,'DATACOVID_4.csv')    #แสดงข้อมูลชุดที่ 4 ออกมาเป็นตาราง
data_4 = pd.read_csv(data_file_path)

# %%
data_4  #แสดงค่า จะเห็นว่ามีค่า missing
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %%
data_4.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                       True
# age                       True
# Unit                      True
# nationality               True
# province_of_isolation    False
# risk                      True
# province_of_onset         True
# district_of_onset         True
# dtype: bool

# %%
data_4_drop = data_4.dropna()  #กำจัดค่า missing โดนใช้ .dropna()
data_4_drop   #แสดงค่า จะเห็นว่าค่า missing หายไปแล้ว
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 357022  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี    Thailand
# 357023  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี    Thailand
# 357024  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี    Thailand
# 357025  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี    Thailand
# 357026  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี    Thailand
#
#        province_of_isolation                                         risk  \
# ...

# %%
data_4_drop.isnull().any() #ไม่มี missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ##รวมData Covid (ตั้งแต่วันที่ 12/01/2020 - 18/03/2022)

# %% [markdown]
# คำอธิบายตาราง
#
# * No. รหัสผู้ป่วย
# * Announce Date วันที่แถลงข่าว
# * Notification Date	วันที่กระทรวงได้รับรายงาน
# * Sex เพศผู้ป่วย
# * Age อายุของผู้ป่วย
# * unit ปี
# * Nationality สัญชาติ
# * Province of isolation จังหวัดที่รักษาตัว
# * risk เสี่ยง
# * Province of onset จังหวัดที่เริ่มพบว่าตัวเองมีอาการป่วย
# * District of onset อำเภอที่เริ่มพบว่าตัวเองมีอาการป่วย

# %%
data_add = pd.concat([data_1_drop,data_2_drop,data_3n_drop,data_4_drop]) #รวมตารางโควิดเข้าด้วยกันโดยใช้ concat
data_add  #แสดงค่า
# Out:
#             No. announce_date Notified date   sex   age Unit     nationality  \
# 47           48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 124         125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 161         162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 181         182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 186         187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...         ...           ...           ...   ...   ...  ...             ...
# 357022  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี        Thailand
# 357023  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี        Thailand
# 357024  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี        Thailand
# 357025  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี        Thailand
# 357026  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี        Thailand
#
# ...

# %%
data_add.isnull().any()  #ดูว่ามีค่า missing มั้ย จะเห็นว่าไม่มีค่า missing แล้ว
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %%
set(data_add['province_of_isolation']) #ดูค่าในคอลัมม์ province_of_isolation ซึ่งพบว่า มีจังหวัด กทม ที่รูปแบบไม่เหมือนแบบอื่น และ ซ้ำกัน
# Out:
# {'กทม',
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
# ...

# %%
data_add['province_of_isolation'].replace({'กทม':'กรุงเทพมหานคร'}, inplace=True) #ใช้คำสั่ง replace แทนที่ตัวที่ผิด

# %%
set(data_add['province_of_isolation']) #ลองรันค่าที่แก้แล้วออกมาดู
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
# ...

# %%
len(set(data_add['province_of_isolation']))  #ดูจำนวน
# Out:
# 78

# %%
set(data_add['province_of_onset'])  #ดูค่าในคอลัมม์ province_of_onset ซึ่งพบว่ามีข้อความที่ซ้ำกัน
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  '\xa0กาญจนบุรี',
#  '\xa0ชลบุรี',
#  '\xa0ตราด',
#  '\xa0นครปฐม',
#  '\xa0สมุทรสงคราม',
#  '\xa0สมุทรสาคร',
#  '\xa0อุทัยธานี',
#  'กทม',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธิ์',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กาฬสินธ์',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขัยนาท',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\t',
#  'ชลบุรี\xa0',
#  'ชอนแก่น',
#  'ชัยนาถ',
#  'ชัยนาท',
#  'ชัยบาดาล',
#  'ชัยภูมิ',
#  'ชัยภูมิ\xa0',
# ...

# %%
data_add['province_of_onset'].replace({'\tประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','USA':'ไม่มีข้อมูล','\xa0กาญจนบุรี':'กาญจนบุรี','\xa0ชลบุรี':'ชลบุรี','\xa0ตราด':'ตราด','\xa0นครปฐม':'นครปฐม',
                                            '\xa0สมุทรสงคราม':'สมุทรสงคราม','\xa0สมุทรสาคร':'สมุทรสาคร','\xa0อุทัยธานี':'อุทัยธานี','กทม':'กรุงเทพมหานคร','กทม.':'กรุงเทพมหานคร','กบินทร์บุรี':'ปราจีนบุรี','กระบี่':'กระบี่',
                                            'กระบี่ี่':'กระบี่','กรุงเทพ':'กรุงเทพมหานคร','กรุงเทพมหานคร':'กรุงเทพมหานคร', 'กรุงเทพมหานคร.':'กรุงเทพมหานคร','กรุงเทพมหานคร. / พระนครศรีอยุธยา':'กรุงเทพมหานคร','กรุงเทพมหานคร. / ศรีสะเกษ':'กรุงเทพมหานคร',
                                            'กรุงเทพฯ':'กรุงเทพมหานคร','กะทู้':'ภูเก็ต','กัมพูชา':'ไม่มีข้อมูล','กาญจนบุรี':'กาญจนบุรี','กาญจบุรี':'กาญจนบุรี','กาญนบุรี':'กาญจนบุรี','กาฬสิน':'กาฬสินธุ์','กาฬสินธิ์':'กาฬสินธุ์','กาฬสินธุ์':'กาฬสินธุ์','กาฬสินธุ์\xa0':'กาฬสินธุ์',
                                            'กาฬสินธ์':'กาฬสินธุ์','กำแพง':'กำแพงเพชร','กำแพงเพชร':'กำแพงเพชร', 'กำแพงเพชร\xa0':'กำแพงเพชร','กําแพงเพชร':'กำแพงเพชร','ขอนแก่น':'ขอนแก่น','ขอนแก่น\xa0':'ขอนแก่น','ขัยนาท':'ชัยนาท',
                                            'ขัยภูมิ':'ชัยภูมิ','ขานุวรลักษณ์บุรี':'กำแพงเพชร','คนไทยเดินทางกลับจากต่างประเทศ':'ไม่มีข้อมูล','คลองเตย':'กรุงเทพมหานคร','จ.กรุงเทพมหานคร':'กรุงเทพมหานคร','จ.ภูเก็ต':'ภูเก็ต', 'จ.ราชบุรี':'ราชบุรี',
                                            'จังหวัดสมุทรสาคร':'สมุทรสาคร','จันทบุรี':'จันทรบุรี','ฉะเชองเทราร':'ฉะเชิงเทรา','ฉะเชิงเทรา':'ฉะเชิงเทรา','ชมพร':'ชุมพร','ชลบุรี':'ชลบุรี','ชลบุรี\t':'ชลบุรี','ชลบุรี\xa0':'ชลบุรี','ชอนแก่น':'ขอนแก่น',
                                            'ชัยนาถ':'ชัยนาท','ชัยนาท':'ชัยนาท','ชัยบาดาล':'ลพบุรี','ชัยภูมิ':'ชัยภูมิ','ชัยภูมิ\xa0':'ชัยภูมิ','ชุมพร':'ชุมพร', 'ชุุมพร':'ชุมพร','ชุุุมพร':'ชุมพร','ดอนมดแดง':'อุบลราชธานี','ดินแดง':'กรุงเทพมหานคร',
                                            'ตรัง':'ตรัง','ตรััง':'ตรัง','ตราด':'ตราด','ตราด\xa0':'ตราด','ตาก':'ตาก','ต่างจังหวัด':'ไม่มีข้อมูล','ทุ่งเสลี่ยม':'สุโขทัย','นคนปฐม':'นครปฐม','นคปฐม':'นครปฐม','นครนปฐม':'นครปฐม',
                                            'นครนาชสีมา':'นครราชสีมา','นครนายก':'นครนายก','นครปฐม':'นครปฐม','นครปฐม\xa0':'นครปฐม','นครปบม':'นครปฐม','นครพนม':'นครพนม','นครพนม\xa0':'นครพนม','นครยายก':'นครนายก',
                                            'นครราชธานี':'นครราชสีมา','นครราชศรีมา':'นครราชสีมา','นครราชสสีมา':'นครราชสีมา','นครราชสีมา':'นครราชสีมา','นครราชสีมา\xa0':'นครราชสีมา',
                                            'นครศรธรรมราช':'นครศรีธรรมราช','นครศรี':'นครศรีธรรมราช','นครศรีธรมราช':'นครศรีธรรมราช','นครศรีธรรมราข':'นครศรีธรรมราช','นครศรีธรรมราช':'นครศรีธรรมราช','นครศรีฯ':'นครศรีธรรมราช',
                                            'นครศรีีธรรมราช':'นครศรีธรรมราช','นครศร๊ธรรมราช':'นครศรีธรรมราช','นครศร๊ะรรมราช':'นครศรีธรรมราช','นครสรรค์':'นครสวรรค์','นครสวรรค':'นครสวรรค์','นครสวรรค์':'นครสวรรค์','นครสวรรค์\xa0':'นครสวรรค์',
                                            'นครสีธรรมราช':'นครศรีธรรมราช','นครฯ':'นครศรีธรรมราช','นคราชสีมา':'นครราชสีมา','นครีศรีธรรมราช':'นครศรีธรรมราช','นตรนายก':'นครนายก','นตรปฐม':'นครปฐม',
                                            'นนทบุรี':'นนทบุรี','นนทบุรี\xa0':'นนทบุรี','นนทุบรี':'นนทบุรี','นนทุรี':'นนทบุรี','นนมบุรี':'นนทบุรี','นรศรีธรรมราช':'นครศรีธรรมราช','นราธิวาส':'นราธิวาส','นราธิวาส\u200b':'นราธิวาส',
                                            'นราธฺวาส':'นราธิวาส','นอกเขต':'ไม่มีข้อมูล','นาราธิวาส':'นราธิวาส','นาวัง':'หนองบัวลำภู','น่าน':'น่าน','น่าน/ฉะเชิงเทรา':'น่าน','บางกรวย':'นนทบุรี','บางกะปิ':'กรุงเทพมหานคร','บางนา':'กรุงเทพมหานคร',
                                            'บางปะอิน':'พระนครศรีอยุธยา','บางละมุง':'ชลบุรี','บางเพียง':'สมุทรปราการ','บึงกาฬ':'บึงกาฬ','บึงโขงหลง':'บึงกาฬ','บุรีรัมภ์':'บุรีรัมย์','บุรีรัมย์':'บุรีรัมย์','บุรีรัมย์\xa0':'บุรีรัมย์','บุรีรีมย์':'บุรีรัมย์',
                                            'ปจ':'ไม่มีข้อมูล','ปทุทธานี':'ปทุมธานี','ปทุมทานี':'ปทุมธานี', 'ปทุมธาน':'ปทุมธานี','ปทุมธานี':'ปทุมธานี','ปทุมธานี.':'ปทุมธานี','ปทุมธานี\xa0':'ปทุมธานี','ปทุมาธานี':'ปทุมธานี',
                                            'ปทุุมธานี':'ปทุมธานี','ปธุมธานี':'ปทุมธานี','ปมุมธานี':'ปทุมธานี','ประจวนคีรีขันธ็':'ประจวบคีรีขันธ์','ประจวบ':'ประจวบคีรีขันธ์','ประจวบคิรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรขันธ์':'ประจวบคีรีขันธ์',
                                            'ประจวบคีรขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขัน':'ประจวบคีรีขันธ์','ประจวบคีรีขันธื':'ประจวบคีรีขันธ์','ประจวบคีรีขันธฺ':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์':'ประจวบคีรีขันธ์','ประจวบคีรีขันธ์\xa0':'ประจวบคีรีขันธ์',
                                            'ประจวบคีรีขันธ์์':'ประจวบคีรีขันธ์','ประจวบคีรีขัันธ์':'ประจวบคีรีขันธ์','ประจวบคีีรีขันธ์':'ประจวบคีรีขันธ์','ประจวบฯ':'ประจวบคีรีขันธ์','ประทุมธานี':'ปทุมธานี',
                                            'ปราจีนบุรี':'ปราจีนบุรี','ปราจีบุรี':'ปราจีนบุรี','ปลวกแดง':'ระยอง','ปลายพระยา':'กระบี่','ปอยเปต':'ไม่มีข้อมูล','ปัตตนรี':'ปัตตานี','ปัตตานนี':'ปัตตานี','ปัตตานี':'ปัตตานี','ปัตตานีี':'ปัตตานี','ปัตาตานี':'ปัตตานี',
                                            'ปััตตานี':'ปัตตานี','ป่าโมก':'อ่างทอง','พม่า':'ไม่มีข้อมูล','พรหมพิราม':'พิษณุโลก','พระนครศรียุธยา':'พระนครศรีอยุธยา','พระนครศรีอยุทธยา':'พระนครศรีอยุธยา',
                                            'พระนครศรีอยุทยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา':'พระนครศรีอยุธยา','พระนครศรีอยุธยา\xa0':'พระนครศรีอยุธยา','พะเยา':'พะเยา','พังงา':'พังงา','พัทยา':'ชลบุรี','พัทลุง':'พัทลุง','พัทลุุง':'พัทลุง',
                                            'พัังงา':'พังงา','พิจิตร':'พิจิตร','พิษณุโลก':'พิษณุโลก','พิษณุโลก\xa0':'พิษณุโลก','พิษณูโลก':'พิษณุโลก','ภาษีเจริญ':'กรุงเทพมหานคร','ภุเก็ต':'ภูเก็ต','ภูุเก็ต':'ภูเก็ต','ภููเก็ต':'ภูเก็ต','ภูเก็ต':'ภูเก็ต',
                                            'ภูเก็็ต':'ภูเก็ต','มหาสาคาม':'มหาสารคาม','มหาสารคาม':'มหาสารคาม','มาเลเซีย':'ไม่มีข้อมูล','มุกดาหาร':'มุกดาหาร','ยะลา':'ยะลา','ยานนาวา':'กรุงเทพมหานคร','ยโสธร':'ยโสธร','ร.จ.จ.นราธิวาส':'นราธิวาส',
                                            'รอ':'ร้อยเอ็ด','ระนอง':'ระนอง','ระยอง':'ระยอง','ระยอง\xa0':'ระยอง','ราชบบุรี':'ราชบุรี','ราชบุรี':'ราชบุรี','ราชบุรี\u200b':'ราชบุรี','ราชุรี':'ราชบุรี','ราชเทวี':'กรุงเทพมหานคร','ร้อยเอ็ด':'ร้อยเอ็ด',
                                            'ลบุรี':'ลพบุรี','ลพบุรี':'ลพบุรี','ลพบุรี.':'ลพบุรี','ลพบุรี\xa0':'ลพบุรี','ลาดกระบัง':'กรุงเทพมหานคร','ลาดพร้าว':'กรุงเทพมหานคร','ลาว':'ไม่มีข้อมูล','ลำปาง':'ลำปาง','ลำพูน':'ลำพูน',
                                            'ลำลูกกา':'ปทุมธานี','วังทอง':'ลำปาง','วิเศษชัยชาญ':'พิษณุโลก','ศรีษะสะเกษ':'ศรีสะเกษ','ศรีษะเกษ':'ศรีสะเกษ','ศรีสระเกษ':'ศรีสะเกษ','ศรีสะเกษ':'ศรีสะเกษ','ศีรสะเกษ':'ศรีสะเกษ',
                                            'สกลนคร':'สกลนคร','สครสวรรค์':'นครสวรรค์','สงขลา':'สงขลา','สงขลา\u200b':'สงขลา','สตูล':'สตูล','สถานที่ทำงาน':'ไม่มีข้อมูล','สพรรณบุรี':'สุพรรณบุรี','สมถทรปราการ':'สมุทรปราการ',
                                            'สมทรสงคราม':'สมุทรสงคราม','สมุครสาคร':'สมุทรสาคร','สมุท':'ไม่มีข้อมูล','สมุทปราการ':'สมุทรปราการ','สมุทรปรากรร':'สมุทรปราการ','สมุทรปรากา':'สมุทรปราการ',
                                            'สมุทรปราการ':'สมุทรปราการ','สมุทรปราการ\xa0':'สมุทรปราการ','สมุทรศาคร':'สมุทรสาคร','สมุทรสงคราม':'สมุทรสงคราม','สมุทรสาคร':'สมุทรสาคร','สมุทรสาคร\xa0':'สมุทรสาคร',
                                            'สมุทรสาคา':'สมุทรสาคร','สมุทรสาคาร':'สมุทรสาคร','สมุทรสาทร':'สมุทรสาคร','สมุทรสารคร':'สมุทรสาคร','สมุทราปราการ':'สมุทรปราการ','สมุทราสาคร':'สมุทรสาคร','สมุทสงคราม':'สมุทรสงคราม',
                                            'สมุทสาคร':'สมุทรสาคร','สมุย':'สุราษฎร์ธานี','สมุุทรปราการ':'สมุทรปราการ','สมุุทรสงคราม':'สมุทรสงคราม','สมุุทรสาคร':'สมุทรสาคร','สระก้ว':'สระแก้ว',
                                            'สระบุรี':'สระบุรี','สระบุรี\xa0':'สระบุรี','สระแก้ว':'สระแก้ว','สวิสเซอร์แลนด์':'ไม่มีข้อมูล','สะพานสูง':'กรุงเทพมหานคร','สะแก้ว':'สระแก้ว','สัตหีบ':'ชลบุรี','สัมผัสผู้ป่วยยืนยัน COVID20':'ไม่มีข้อมูล',
                                            'สิงห์บุรี':'สิงห์บุรี','สิงห์บุรี\xa0':'สิงห์บุรี','สุทรปราการ':'สมุทรปราการ','สุพรรญบุรี':'สุพรรณบุรี','สุพรรณบุรั':'สุพรรณบุรี','สุพรรณบุรี':'สุพรรณบุรี','สุมทรปราการ':'สมุทรปราการ',
                                            'สุมทรสาคร':'สมุทรสาคร','สุมุทรปราการ':'สมุทรปราการ','สุมุทรสาคร':'สมุทรสาคร','สุระบุรี':'สระบุรี','สุราษ':'สุราษฎร์ธานี','สุราษฎณ์ธานี':'สุราษฎร์ธานี','สุราษฎธานี':'สุราษฎร์ธานี',
                                            'สุราษฎร์':'สุราษฎร์ธานี','สุราษฎร์ธานี':'สุราษฎร์ธานี','สุราษฎร์ฯ':'สุราษฎร์ธานี','สุราษฎร์์ธานี':'สุราษฎร์ธานี','สุราษฎ์ธานี':'สุราษฎร์ธานี','สุราษฏร์ธานี':'สุราษฎร์ธานี','สุราษธานี':'สุราษฎร์ธานี',
                                            'สุราษร์ฎธานี':'สุราษฎร์ธานี','สุราษร์ธานี':'สุราษฎร์ธานี','สุราษฯ':'สุราษฎร์ธานี','สุรินทรื':'สุรินทร์','สุรินทร์':'สุรินทร์','สุรินทร์ 32150':'สุรินทร์','สุรินทร์,รีสะเกษ':'สุรินทร์','สุรินทร์\xa0':'สุรินทร์',
                                            'สุริมทร์':'สุรินทร์','สุริะแก้ว':'สระแก้ว','สุวรรณภูมิ':'สมุทรปราการ','สุุราษฎร์ธานี':'สุราษฎร์ธานี','สุุราษฏร์ธานี':'สุราษฎร์ธานี','สุุราษฯ':'สุราษฎร์ธานี','สุุรินทร์':'สุรินทร์','สุุุโขทัย':'สุโขทัย','สุโขทับ':'สุโขทัย',
                                            'สุโขทัย':'สุโขทัย','สุโขทัย\xa0':'สุโขทัย','หนวงบัวลำภู':'หนองบัวลำภู','หนองคาย':'หนองคาย','หนองงคาย':'หนองคาย','หนองบัวภู':'หนองบัวลำภู','หนองบัวลำพูน':'หนองบัวลำพูน','หนองบัวลำภู':'หนองบัวลำภู',
                                            'หนองบัวลําภู':'หนองบัวลำภู','หนองบััวลำภู':'หนองบัวลำภู','หัวหิน':'ประจวบคีรีขันธ์','ห้วยขวาง':'กรุงเทพมหานคร','อยุทธยา':'พระนครศรีอยุธยา','อยุธยา':'พระนครศรีอยุธยา','อำนาจเจริญ':'อำนาจเจริญ',
                                            'อำนาญเจริญ':'อำนาจเจริญ','อำนาเจริญ':'อำนาจเจริญ','อิสราเอล':'ไม่มีข้อมูล','อุดธานี':'อุดรธานี','อุดร':'อุดรธานี','อุดรธาณี':'อุดรธานี','อุดรธานี':'อุดรธานี','อุดรธานี\xa0':'อุดรธานี','อุดรธานีี':'อุดรธานี','อุดรราชธานี':'อุดรธานี',
                                            'อุตรดิตถ์':'อุตรดิตถ์','อุตรดิตถ์\xa0':'อุตรดิตถ์','อุตรดิตถ์์':'อุตรดิตถ์','อุตรดิิตถ์':'อุตรดิตถ์','อุตรติดถ์':'อุตรดิตถ์','อุทัยธานี':'อุทัยธานี','อุทัยานี':'อุทัยธานี','อุบลราขธานี':'อุบลราชธานี','อุบลราชธานี':'อุบลราชธานี',
                                            'อุบลราชธานี\xa0':'อุบลราชธานี','อุุครดิตถ์':'อุตรดิตถ์','อุุดรธาน':'อุตรดิตถ์','อุุดรธานี':'อุดรธานี','อุุตรดิตถ์':'อุตรดิตถ์','อุุทัยธานี':'อุทัยธานี','อ่งทอง':'อ่างทอง','อ่างทอง':'อ่างทอง','อ่างทอง\xa0':'อ่างทอง',
                                            'อํานาจเจริญ':'อำนาจเจริญ','เชิงเทรา':'ฉะเชิงเทรา','เชียงราย':'เชียงราย','เชียงใหม่':'เชียงใหม่','เชีียงราย':'เชียงราย','เพขรบุรี':'เพชรบุรี','เพขรบูรณื':'เพชรบูรณ์','เพขรบูรณ์':'เพชรบูรณ์','เพชรบุรณ์':'เพชรบูรณ์',
                                            'เพชรบุรี':'เพชรบุรี','เพชรบุรึ':'เพชรบุรี','เพชรบุุรี':'เพชรบุรี','เพชรบุูรณ์':'เพชรบูรณ์','เพชรบูรณ์':'เพชรบูรณ์','เพชรบูรณ์\xa0':'เพชรบูรณ์','เพชรบูร์':'เพชรบูรณ์','เพชรบููรณ์':'เพชรบูรณ์','เมือง':'ไม่มีข้อมูล',
                                            'เมืองตาก':'ตาก','เมืองน่าน':'น่าน','เมืองปัตตานี':'ปัตตานี','เรือ':'ไม่มีข้อมูล','เลย':'เลย','เลย\xa0':'เลย','เวียงจันทร์':'ไม่มีข้อมูล','แพร่':'แพร่','แม่ทะ':'ลำปาง','แม่ฮ่องสอน':'แม่ฮ่องสอน','แล้วป่วย':'ไม่มีข้อมูล','โพธิ์ทอง':'อ่างทอง',
                                            'ไชโย':'อ่างทอง','ขลบุรี':'ชลบุรี','ไม่ระบุ':'ไม่มีข้อมูล'}, inplace=True)

# %%
set(data_add['province_of_onset'])   #ดูข้อมูลที่แก้แล้ว
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทรบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำพูน',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
# ...

# %%
len(set(data_add['province_of_onset']))  #เช็กจำนวน
# Out:
# 79

# %%
data_add.isnull().any()  #ตรวจสอบว่ามีค่า missing มั้ย
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# #ข้อมูลชุดที่ 2 ข้อมูลที่สนใจ คือ ข้อมูลผู้ป่วยระลอก 3 (ตั้งแต่ 01/04/2021 –ปัจจุบัน)

# %%
data_file_path = os.path.join(path,'wave3_covid.csv')    
data_5 = pd.read_csv(data_file_path)

# %%
data_5
# Out:
#      txn_date gender  age_number age_range nationality  \
# 0      1/4/21    ชาย        29.0  20-29 ปี       Burma
# 1      1/4/21    ชาย        33.0  30-39 ปี    Thailand
# 2      1/4/21    ชาย        24.0  20-29 ปี    Thailand
# 3      1/4/21   หญิง        62.0  60-69 ปี    Thailand
# 4      1/4/21    ชาย        27.0  20-29 ปี       Burma
# ...       ...    ...         ...       ...         ...
# 4995  13/4/21   หญิง        32.0  30-39 ปี         NaN
# 4996  13/4/21    ชาย        21.0  20-29 ปี         NaN
# 4997  13/4/21   หญิง        27.0  20-29 ปี         NaN
# 4998  13/4/21   หญิง        24.0  20-29 ปี         NaN
# 4999  13/4/21    ชาย        30.0  30-39 ปี         NaN
#
#                                         job  \
# 0                  รับจ้างทั่วไป / ฟรีแลนซ์
# 1     ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ
# 2                                       NaN
# 3                                       NaN
# 4                      พนักงานบริษัท/โรงงาน
# ...

# %% [markdown]
# เชค missing

# %%
data_5.isnull().any() #False = ไม่มี Missing True = มี Missing พบว่า มี missing ทุกคอลัมน์
# Out:
# txn_date        False
# gender          False
# age_number       True
# age_range       False
# nationality      True
# job              True
# risk             True
# patient_type    False
# province        False
# dtype: bool

# %%
data_5['age_number'].mean()
# Out:
# 31.436383344065252

# %%
data_5fill= data_5.fillna(value={'risk':'ไม่ระบุ', 'nationality':'ไม่ระบุ', 'job':'ไม่ระบุ','age_number':data_5['age_number'].mean()})
data_5fill
# Out:
#      txn_date gender  age_number age_range nationality  \
# 0      1/4/21    ชาย        29.0  20-29 ปี       Burma
# 1      1/4/21    ชาย        33.0  30-39 ปี    Thailand
# 2      1/4/21    ชาย        24.0  20-29 ปี    Thailand
# 3      1/4/21   หญิง        62.0  60-69 ปี    Thailand
# 4      1/4/21    ชาย        27.0  20-29 ปี       Burma
# ...       ...    ...         ...       ...         ...
# 4995  13/4/21   หญิง        32.0  30-39 ปี     ไม่ระบุ
# 4996  13/4/21    ชาย        21.0  20-29 ปี     ไม่ระบุ
# 4997  13/4/21   หญิง        27.0  20-29 ปี     ไม่ระบุ
# 4998  13/4/21   หญิง        24.0  20-29 ปี     ไม่ระบุ
# 4999  13/4/21    ชาย        30.0  30-39 ปี     ไม่ระบุ
#
#                                         job  \
# 0                  รับจ้างทั่วไป / ฟรีแลนซ์
# 1     ข้าราชการ/พนักงานของรัฐ / รัฐวิสาหกิจ
# 2                                   ไม่ระบุ
# 3                                   ไม่ระบุ
# 4                      พนักงานบริษัท/โรงงาน
# ...

# %%
data_5fill.isnull().any()
# Out:
# txn_date        False
# gender          False
# age_number      False
# age_range       False
# nationality     False
# job             False
# risk            False
# patient_type    False
# province        False
# dtype: bool

# %% [markdown]
# #ข้อมูลชุดที่ 3 ข้อมูลภูมิภาค

# %%
dataregion = [['อำนาจเจริญ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['บึงกาฬ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['บุรีรัมย์','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['ชัยภูมิ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['กาฬสินธุ์','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['ขอนแก่น','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['เลย','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['มหาสารคาม','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['มุกดาหาร','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['นครพนม','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['นครราชสีมา','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['หนองบัวลำภู','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['หนองคาย','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['ร้อยเอ็ด','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['สกลนคร','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['ศรีสะเกษ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['สุรินทร์','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['อุบลราชธานี','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['อุดรธานี','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['ยโสธร','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ'],
                ['เชียงใหม่','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['เชียงราย','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['ลำปาง','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['ลำพูน','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['แม่ฮ่องสอน','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['น่าน','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['พะเยา','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['แพร่','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['อุตรดิตถ์','เหนือ','เหนือ','เหนือ','เหนือ'],
                ['ตาก','ตะวันออก','เหนือ','เหนือ','เหนือ'],
                ['สุโขทัย','กลาง','เหนือ','เหนือ','เหนือ'],
                ['พิษณุโลก','กลาง','เหนือ','เหนือ','เหนือ'],
                ['พิจิตร','กลาง','เหนือ','เหนือ','เหนือ'],
                ['กำแพงเพชร','กลาง','เหนือ','เหนือ','เหนือ'],
                ['เพชรบูรณ์','กลาง','เหนือ','เหนือ','เหนือ'],
                ['นครสวรรค์','กลาง','เหนือ','กลาง','เหนือ'],
                ['อุทัยธานี','กลาง','เหนือ','กลาง','เหนือ'],
                ['อ่างทอง','กลาง','กลาง','กลาง','กลาง'],
                ['ชัยนาท','กลาง','กลาง','กลาง','กลาง'],
                ['พระนครศรีอยุธยา','กลาง','กลาง','กลาง','กลาง'],
                ['กรุงเทพมหานคร','กลาง','กลาง','กลาง','กลาง'],
                ['ลพบุรี','กลาง','กลาง','กลาง','กลาง'],
                ['นครปฐม','กลาง','กลาง','กลาง','กลาง'],
                ['นนทบุรี','กลาง','กลาง','กลาง','กลาง'],
                ['ปทุมธานี','กลาง','กลาง','กลาง','กลาง'],
                ['สมุทรปราการ','กลาง','กลาง','กลาง','กลาง'],
                ['สมุทรสาคร','กลาง','กลาง','กลาง','กลาง'],
                ['สมุทรสงคราม','กลาง','กลาง','กลาง','กลาง'],
                ['สระบุรี','กลาง','กลาง','กลาง','กลาง'],
                ['สิงห์บุรี','กลาง','กลาง','กลาง','กลาง'],
                ['สุพรรณบุรี','กลาง','กลาง','กลาง','กลาง'],
                ['นครนายก','กลาง','กลาง','ตะวันออก','กลาง'],
                ['ฉะเชิงเทรา','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
                ['จันทบุรี','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
                ['ชลบุรี','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
                ['ปราจีนบุรี','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
                ['ระยอง','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
                ['สระแก้ว','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
                ['ตราด','ตะวันออก','กลาง','ตะวันออก','ตะวันออก'],
                ['กาญจนบุรี','ตะวันตก','กลาง','กลาง','กลาง'],
                ['ราชบุรี','ตะวันตก','กลาง','กลาง','กลาง'],
                ['เพชรบุรี','ตะวันตก','กลาง','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','กลาง'],
                ['ประจวบคีรีขันธ์','ตะวันตก','กลาง','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','กลาง'],
                ['ชุมพร','ใต้','ใต้','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้'],
                ['นครศรีธรรมราช','ใต้','ใต้','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้'],
                ['นราธิวาส','ใต้','ใต้','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้'],
                ['ปัตตานี','ใต้','ใต้','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้'],
                ['พัทลุง','ใต้','ใต้','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้'],
                ['สงขลา','ใต้','ใต้','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้'],
                ['สุราษฎร์ธานี','ใต้','ใต้','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้'],
                ['ยะลา','ใต้','ใต้','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้'],
                ['กระบี่','ใต้','ใต้','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้'],
                ['พังงา','ใต้','ใต้','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้'],
                ['ภูเก็ต','ใต้','ใต้','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้'],
                ['ระนอง','ใต้','ใต้','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้'],
                ['สตูล','ใต้','ใต้','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้'],
                ['ตรัง','ใต้','ใต้','ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน','ใต้']]  

header = ['จังหวัด','6 ภูมิภาค (ภูมิศาสตร์)','4 ภูมิภาค (การเมือง)','6 ภูมิภาค (อุตุนิยมวิทยา)','5 ภูมิภาค (การท่องเที่ยว)']  #หัวตาราง

# %%
df_dataregion = pd.DataFrame.from_records(dataregion,columns=header) #สร้างข้อมูลออกมาเป็นในรูปแบบตาราง
df_dataregion
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# ..         ...                    ...                  ...
# 72       พังงา                    ใต้                  ใต้
# 73      ภูเก็ต                    ใต้                  ใต้
# 74       ระนอง                    ใต้                  ใต้
# 75        สตูล                    ใต้                  ใต้
# 76        ตรัง                    ใต้                  ใต้
#
#          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)
# 0               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 1               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# 2               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ
# ...

# %%
df_dataregion.isnull().any()   #False = ไม่มี Missing True = มี Missing พบว่า มี missing ทุกคอลัมน์ #จะเห็นว่าไม่มี missing
# Out:
# จังหวัด                      False
# 6 ภูมิภาค (ภูมิศาสตร์)       False
# 4 ภูมิภาค (การเมือง)         False
# 6 ภูมิภาค (อุตุนิยมวิทยา)    False
# 5 ภูมิภาค (การท่องเที่ยว)    False
# dtype: bool

# %% [markdown]
# ##เพิ่มพิกัด

# %%
# !pip install geopandas #ทำการติดตั้ง  geopandas

# %%
import geopandas # For working with geographical data
import pandas as pd

# %%
th_geojson=geopandas.read_file('/content/drive/MyDrive/DATA_Final_Project/thai.json') #ดึงข้อมูลจากไดร์ฟ ที่ชื่อว่า thai.json จากโฟร์เดอร์ DATA_Final_Project
th_geojson.head() #แสดงค่า เอาแค่ส่วนด้านบน
# Out:
#                   name                                           geometry
# 0         Mae Hong Son  POLYGON ((98.47780 19.70563, 98.48260 19.66410...
# 1             Chumphon  POLYGON ((99.50343 10.99705, 99.51157 10.86636...
# 2  Nakhon Si Thammarat  POLYGON ((100.12963 7.80172, 100.04457 7.82446...
# 3               Phuket  POLYGON ((98.41863 7.90375, 98.43165 7.91743, ...
# 4            Phang-nga  MULTIPOLYGON (((98.53631 8.11514, 98.60239 8.0...

# %%
th_geojson #แสดงค่าทั้งหมด
# Out:
#                    name                                           geometry
# 0          Mae Hong Son  POLYGON ((98.47780 19.70563, 98.48260 19.66410...
# 1              Chumphon  POLYGON ((99.50343 10.99705, 99.51157 10.86636...
# 2   Nakhon Si Thammarat  POLYGON ((100.12963 7.80172, 100.04457 7.82446...
# 3                Phuket  POLYGON ((98.41863 7.90375, 98.43165 7.91743, ...
# 4             Phang-nga  MULTIPOLYGON (((98.53631 8.11514, 98.60239 8.0...
# ..                  ...                                                ...
# 72        Nakhon Phanom  POLYGON ((104.75791 16.81889, 104.73452 16.804...
# 73             Mukdahan  POLYGON ((104.75791 16.81889, 104.77901 16.704...
# 74           Narathiwat  POLYGON ((101.72350 6.57438, 101.80836 6.46454...
# 75              Pattani  POLYGON ((101.72350 6.57438, 101.67837 6.57712...
# 76            Bueng Kan  POLYGON ((104.20333 18.01864, 104.12468 17.999...
#
# [77 rows x 2 columns]

# %%
set(th_geojson['name']) #ดูค่าในคอลัมม์ name
# Out:
# {'Amnat Charoen',
#  'Ang Thong',
#  'Bangkok',
#  'Bueng Kan',
#  'Buri Ram',
#  'Chachoengsao',
#  'Chai Nat',
#  'Chaiyaphum',
#  'Chanthaburi',
#  'Chiang Mai',
#  'Chiang Rai',
#  'Chon Buri',
#  'Chumphon',
#  'Kalasin',
#  'Kamphaeng Phet',
#  'Kanchanaburi',
#  'Khon Kaen',
#  'Krabi',
#  'Lampang',
#  'Lamphun',
#  'Loei',
#  'Lop Buri',
#  'Mae Hong Son',
#  'Maha Sarakham',
#  'Mukdahan',
#  'Nakhon Nayok',
#  'Nakhon Pathom',
#  'Nakhon Phanom',
#  'Nakhon Ratchasima',
#  'Nakhon Sawan',
#  'Nakhon Si Thammarat',
#  'Nan',
#  'Narathiwat',
#  'Nong Bua Lam Phu',
#  'Nong Khai',
#  'Nonthaburi',
#  'Pathum Thani',
#  'Pattani',
#  'Phang-nga',
#  'Phatthalung',
#  'Phayao',
#  'Phetchabun',
#  'Phetchaburi',
#  'Phichit',
#  'Phitsanulok',
#  'Phra Nakhon Si Ayutthaya',
#  'Phrae',
#  'Phuket',
#  'Prachin Buri',
#  'Prachuap Khiri Khan',
#  'Ranong',
#  'Ratchaburi',
#  'Rayong',
#  'Roi Et',
#  'Sa kaeo',
#  'Sakon Nakhon',
#  'Samut Prakarn',
#  'Samut Sakhon',
# ...

# %%
th_geojson['name'].replace({'Prachuap Khiri Khan':'ประจวบคีรีขันธ์','Kanchanaburi':'กาญจนบุรี','Chon Buri':'ชลบุรี','Trat':'ตราด','Nakhon Pathom':'นครปฐม',
                                            'Samut Songkhram':'สมุทรสงคราม','Samut Sakhon':'สมุทรสาคร','Uthai Thani':'อุทัยธานี','Bangkok':'กรุงเทพมหานคร','Prachin Buri':'ปราจีนบุรี','Krabi':'กระบี่',
                                             'Phra Nakhon Si Ayutthaya':'พระนครศรีอยุธยา','Si Sa Ket':'ศรีสะเกษ','Phuket':'ภูเก็ต','Kalasin':'กาฬสินธุ์','Kamphaeng Phet':'กำแพงเพชร','Khon Kaen':'ขอนแก่น','Chai Nat':'ชัยนาท',
                                            'Chaiyaphum':'ชัยภูมิ','Ratchaburi':'ราชบุรี','Chanthaburi':'จันทรบุรี','Chachoengsao':'ฉะเชิงเทรา','Chumphon':'ชุมพร','Lop Buri':'ลพบุรี','Ubon Ratchathani':'อุบลราชธานี','Trang':'ตรัง','Tak':'ตาก','Sukhothai':'สุโขทัย','Nakhon Ratchasima':'นครราชสีมา','Nakhon Nayok':'นครนายก','Nakhon Phanom':'นครพนม',
                                            'Nakhon Si Thammarat':'นครศรีธรรมราช','Nakhon Sawan':'นครสวรรค์','Nonthaburi':'นนทบุรี','Narathiwat':'นราธิวาส','Nong Bua Lam Phu':'หนองบัวลำภู','Nan':'น่าน','Samut Prakarn':'สมุทรปราการ','Bueng Kan':'บึงกาฬ','Buri Ram':'บุรีรัมย์',
                                            'Pathum Thani':'ปทุมธานี','Rayong':'ระยอง','Pattani':'ปัตตานี','Ang Thong':'อ่างทอง','Phitsanulok':'พิษณุโลก','Phayao':'พะเยา','Phang-nga':'พังงา','Phatthalung':'พัทลุง','Phichit':'พิจิตร','Maha Sarakham':'มหาสารคาม','Mukdahan':'มุกดาหาร','Yala':'ยะลา','Yasothon':'ยโสธร',
                                            'Roi Et':'ร้อยเอ็ด','Ranong':'ระนอง','Lampang':'ลำปาง','Lamphun':'ลำพูน','Sakon Nakhon':'สกลนคร','Songkhla':'สงขลา','Satun':'สตูล','Suphan Buri':'สุพรรณบุรี',
                                            'Sa kaeo':'สระแก้ว','Saraburi':'สระบุรี','Sing Buri':'สิงห์บุรี','Surat Thani':'สุราษฎร์ธานี',
                                            'Surin':'สุรินทร์','Nong Khai':'หนองคาย','Amnat Charoen':'อำนาจเจริญ',
                                            'Udon Thani':'อุดรธานี','Uttaradit':'อุตรดิตถ์','Chiang Rai':'เชียงราย','Chiang Mai':'เชียงใหม่','Phetchaburi':'เพชรบุรี','Phetchabun':'เพชรบูรณ์',
                                            'Loei':'เลย','Phrae':'แพร่','Mae Hong Son':'แม่ฮ่องสอน'}, inplace=True) #ใช้ replace ใช้การแก้จากจังหวัดเป็นภาษาอังกฤษให้เป็นไทย

# %%
set(th_geojson['name']) #ดูค่าในคอลัมม์ name ที่แก้แล้ว
# Out:
# {'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'จันทรบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
#  'อุดรธานี',
#  'อุตรดิตถ์',
#  'อุทัยธานี',
# ...

# %%
th_geojson #ลองรันตารางใหม่อีกรอบหลังจากแก้ชื่แล้ว
# Out:
#              name                                           geometry
# 0      แม่ฮ่องสอน  POLYGON ((98.47780 19.70563, 98.48260 19.66410...
# 1           ชุมพร  POLYGON ((99.50343 10.99705, 99.51157 10.86636...
# 2   นครศรีธรรมราช  POLYGON ((100.12963 7.80172, 100.04457 7.82446...
# 3          ภูเก็ต  POLYGON ((98.41863 7.90375, 98.43165 7.91743, ...
# 4           พังงา  MULTIPOLYGON (((98.53631 8.11514, 98.60239 8.0...
# ..            ...                                                ...
# 72         นครพนม  POLYGON ((104.75791 16.81889, 104.73452 16.804...
# 73       มุกดาหาร  POLYGON ((104.75791 16.81889, 104.77901 16.704...
# 74       นราธิวาส  POLYGON ((101.72350 6.57438, 101.80836 6.46454...
# 75        ปัตตานี  POLYGON ((101.72350 6.57438, 101.67837 6.57712...
# 76         บึงกาฬ  POLYGON ((104.20333 18.01864, 104.12468 17.999...
#
# [77 rows x 2 columns]

# %% [markdown]
# ##รวมตาราง ภูมิภาคเข้ากับพิกัด

# %%
dataregion_th_geojson = df_dataregion.merge(th_geojson,how='left',left_on='จังหวัด',right_on='name')
dataregion_th_geojson
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์) 4 ภูมิภาค (การเมือง)  \
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ   ตะวันออกเฉียงเหนือ
# ..         ...                    ...                  ...
# 72       พังงา                    ใต้                  ใต้
# 73      ภูเก็ต                    ใต้                  ใต้
# 74       ระนอง                    ใต้                  ใต้
# 75        สตูล                    ใต้                  ใต้
# 76        ตรัง                    ใต้                  ใต้
#
#          6 ภูมิภาค (อุตุนิยมวิทยา) 5 ภูมิภาค (การท่องเที่ยว)        name  \
# 0               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ  อำนาจเจริญ
# 1               ตะวันออกเฉียงเหนือ        ตะวันออกเฉียงเหนือ      บึงกาฬ
# ...

# %% [markdown]
# ##เลือกเฉพาะภูมิภาคที่ต้องการใช้

# %%
dataregion_th_geojson.drop(['4 ภูมิภาค (การเมือง)','6 ภูมิภาค (อุตุนิยมวิทยา)','5 ภูมิภาค (การท่องเที่ยว)','name'], axis=1, inplace=True)   #drop ข้อมูลออกให้เหลือเฉพาะอันที่เราต้องการ
dataregion_th_geojson
# Out:
#        จังหวัด 6 ภูมิภาค (ภูมิศาสตร์)  \
# 0   อำนาจเจริญ     ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ     ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์     ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ     ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์     ตะวันออกเฉียงเหนือ
# ..         ...                    ...
# 72       พังงา                    ใต้
# 73      ภูเก็ต                    ใต้
# 74       ระนอง                    ใต้
# 75        สตูล                    ใต้
# 76        ตรัง                    ใต้
#
#                                              geometry
# 0   POLYGON ((105.10698 16.09585, 105.09124 16.054...
# 1   POLYGON ((104.20333 18.01864, 104.12468 17.999...
# 2   POLYGON ((103.11575 15.48229, 103.10268 15.428...
# 3   POLYGON ((101.75144 16.67035, 101.78855 16.642...
# 4   POLYGON ((103.65014 17.04387, 103.64719 17.021...
# ..                                                ...
# 72  MULTIPOLYGON (((98.53631 8.11514, 98.60239 8.0...
# 73  POLYGON ((98.41863 7.90375, 98.43165 7.91743, ...
# ...

# %% [markdown]
# #รวมตารางข้อมูลทั้งหมด
#
#
# * Data Covid (ตั้งแต่วันที่ 12/01/2020 - 18/03/2022)  (data_add3)
# * ข้อมูลสถิติการรับรองและสถานะการรับรองของสถานพยาบาลตามมาตรฐาน HA ขั้น 1-3 และ Advanced-HA  (data_5re_drop)
# * ข้อมูลภูมิภาค (df_dataregion)

# %% [markdown]
# รวมตาราง Covid กับ ตาราง ภูมิภาค

# %% [markdown]
# ##รวมตาราง ข้อมูลโควิด Covid กับ ตาราง ภูมิภาค

# %%
data_total1 = data_add.merge(dataregion_th_geojson,how='left',left_on='province_of_onset',right_on='จังหวัด') #รวมตาราง data_add ข้อมูลโควิดที่รวมกัน 4 ตาราง merge กับตารางภูมิภา
data_total1
# Out:
#              No. announce_date Notified date   sex   age Unit     nationality  \
# 0             48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 1            125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 2            162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 3            182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 4            187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...          ...           ...           ...   ...   ...  ...             ...
# 2361302  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี        Thailand
# 2361303  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี        Thailand
# 2361304  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี        Thailand
# 2361305  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี        Thailand
# 2361306  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี        Thailand
#
# ...

# %%
data_total1.isnull().any()  #ยังมีค่า missing
# Out:
# No.                       False
# announce_date             False
# Notified date             False
# sex                       False
# age                       False
# Unit                      False
# nationality               False
# province_of_isolation     False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# จังหวัด                    True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# geometry                   True
# dtype: bool

# %%
data_total1.isnull().any() #ดูว่ามีค่า missing มั้ย จะเห็นว่ายังมี missing อยู่
# Out:
# No.                       False
# announce_date             False
# Notified date             False
# sex                       False
# age                       False
# Unit                      False
# nationality               False
# province_of_isolation     False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# จังหวัด                    True
# 6 ภูมิภาค (ภูมิศาสตร์)     True
# geometry                   True
# dtype: bool

# %%
data_total1_drop = data_total1.dropna() #กำจัดค่า missng
data_total1_drop #แสดงค่า
# Out:
#              No. announce_date Notified date   sex   age Unit     nationality  \
# 0             48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 1            125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 2            162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 3            182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 4            187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...          ...           ...           ...   ...   ...  ...             ...
# 2361302  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี        Thailand
# 2361303  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี        Thailand
# 2361304  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี        Thailand
# 2361305  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี        Thailand
# 2361306  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี        Thailand
#
# ...

# %%
data_total1_drop.isnull().any()  #ไม่มี missing แล้ว
# Out:
# No.                       False
# announce_date             False
# Notified date             False
# sex                       False
# age                       False
# Unit                      False
# nationality               False
# province_of_isolation     False
# risk                      False
# province_of_onset         False
# district_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# geometry                  False
# dtype: bool

# %%
year1=list()
for each_row in data_total1_drop.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        year1.append(True)
    else:
        year1.append(False)

# %%
data2021 = data_total1_drop[year1]
data2021
# Out:
#              No. announce_date Notified date   sex   age Unit  \
# 1            125      6/3/2021      5/3/2021  หญิง  55.0   ปี
# 3719        6886      1/1/2021    31/12/2020  หญิง  40.0   ปี
# 3720        6887      1/1/2021    31/12/2020  หญิง  21.0   ปี
# 3721        6888      1/1/2021    31/12/2020  หญิง  20.0   ปี
# 3722        6889      1/1/2021    31/12/2020  หญิง  47.0   ปี
# ...          ...           ...           ...   ...   ...  ...
# 1625139  2223277    31/12/2021    30/12/2021   ชาย  33.0   ปี
# 1625140  2223278    31/12/2021    30/12/2021  หญิง  30.0   ปี
# 1625141  2223279    31/12/2021    30/12/2021   ชาย  43.0   ปี
# 1625142  2223280    31/12/2021    30/12/2021  หญิง  30.0   ปี
# 1625143  2223281    31/12/2021    30/12/2021  หญิง  18.0   ปี
#
#                nationality province_of_isolation                 risk  \
# 1                 Thailand              ปทุมธานี  Cluster ตลาดพรพัฒน์
# 3719              Thailand         กรุงเทพมหานคร    Cluster สมุทรสาคร
# ...

# %%
ym_14=list() #ประกาศ ym_14 เป็น list ว่าง
for each_row in data2021.iterrows():  #เขียนลูปในตาราง data2021
    if each_row[1]['announce_date'].split('/')[1] == '4':
        ym_14.append(True)
    else:
        ym_14.append(False)

# %%
data2021m4 = data2021[ym_14]
data2021m4
# Out:
#          No. announce_date Notified date   sex   age Unit nationality  \
# 20689  28864      1/4/2021     31/3/2021   ชาย  27.0   ปี       Burma
# 20690  28865      1/4/2021     31/3/2021  หญิง  18.0   ปี       Burma
# 20691  28866      1/4/2021     31/3/2021   ชาย  28.0   ปี       Burma
# 20692  28867      1/4/2021     31/3/2021  หญิง  30.0   ปี       Burma
# 20693  28868      1/4/2021     31/3/2021  หญิง  30.0   ปี       Burma
# ...      ...           ...           ...   ...   ...  ...         ...
# 45833  65149     30/4/2021     29/4/2021  หญิง  26.0   ปี    Thailand
# 45834  65150     30/4/2021     29/4/2021   ชาย  28.0   ปี    Thailand
# 45835  65151     30/4/2021     29/4/2021   ชาย  25.0   ปี    Thailand
# 45836  65152     30/4/2021     29/4/2021  หญิง  26.0   ปี    Thailand
# 45837  65153     30/4/2021     29/4/2021   ชาย  68.0   ปี    Thailand
#
#       province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ##รวม 3 ตาราง ข้อมูล covid,ภูมิภาค และข้อมูลผู้ป่วยระลอก 1 ถึงระลอก 2 (ตั้งแต่ 12/01/2020 – 31/03/2021)

# %%
data_total3 = data_5fill.merge(data2021m4,how='right',left_on='txn_date',right_on='announce_date') #ทำการ merge โดยตาราง data_total1 อยู่ด้านซ้าย และ ตาราง data_5fill อยู่ด้านขวา เชื่อมกันด้วยวันที่
data_total3 #แสดงค่า
# Out:
#       txn_date gender  age_number age_range nationality_x  job risk_x  \
# 0          NaN    NaN         NaN       NaN           NaN  NaN    NaN
# 1          NaN    NaN         NaN       NaN           NaN  NaN    NaN
# 2          NaN    NaN         NaN       NaN           NaN  NaN    NaN
# 3          NaN    NaN         NaN       NaN           NaN  NaN    NaN
# 4          NaN    NaN         NaN       NaN           NaN  NaN    NaN
# ...        ...    ...         ...       ...           ...  ...    ...
# 24952      NaN    NaN         NaN       NaN           NaN  NaN    NaN
# 24953      NaN    NaN         NaN       NaN           NaN  NaN    NaN
# 24954      NaN    NaN         NaN       NaN           NaN  NaN    NaN
# 24955      NaN    NaN         NaN       NaN           NaN  NaN    NaN
# 24956      NaN    NaN         NaN       NaN           NaN  NaN    NaN
#
#       patient_type province    No.  ...   age Unit nationality_y  \
# ...

# %%
data_total2 = data2021m4.merge(data_5fill,how='left',left_on='announce_date',right_on='txn_date') #ทำการ merge โดยตาราง data_total1 อยู่ด้านซ้าย และ ตาราง data_5fill อยู่ด้านขวา เชื่อมกันด้วยวันที่
data_total2 #แสดงค่า
# Out:
#          No. announce_date Notified date   sex   age Unit nationality_x  \
# 0      28864      1/4/2021     31/3/2021   ชาย  27.0   ปี         Burma
# 1      28865      1/4/2021     31/3/2021  หญิง  18.0   ปี         Burma
# 2      28866      1/4/2021     31/3/2021   ชาย  28.0   ปี         Burma
# 3      28867      1/4/2021     31/3/2021  หญิง  30.0   ปี         Burma
# 4      28868      1/4/2021     31/3/2021  หญิง  30.0   ปี         Burma
# ...      ...           ...           ...   ...   ...  ...           ...
# 24952  65149     30/4/2021     29/4/2021  หญิง  26.0   ปี      Thailand
# 24953  65150     30/4/2021     29/4/2021   ชาย  28.0   ปี      Thailand
# 24954  65151     30/4/2021     29/4/2021   ชาย  25.0   ปี      Thailand
# 24955  65152     30/4/2021     29/4/2021  หญิง  26.0   ปี      Thailand
# 24956  65153     30/4/2021     29/4/2021   ชาย  68.0   ปี      Thailand
#
#       province_of_isolation                                       risk_x  \
# ...

# %%
data_total2.isnull().any() #ดูว่ามีค่า missng มั้ย จะเห็นว่ายังมีค่า missing อยู่
# Out:
# No.                       False
# announce_date             False
# Notified date             False
# sex                       False
# age                       False
# Unit                      False
# nationality_x             False
# province_of_isolation     False
# risk_x                    False
# province_of_onset         False
# district_of_onset         False
# จังหวัด                   False
# 6 ภูมิภาค (ภูมิศาสตร์)    False
# geometry                  False
# txn_date                   True
# gender                     True
# age_number                 True
# age_range                  True
# nationality_y              True
# job                        True
# risk_y                     True
# patient_type               True
# province                   True
# dtype: bool

# %%
data_total2_drop = data_total2.dropna() #กำจัดค่า missng 
data_total2_drop #แสดงค่าจะเห็นว่าไม่มีค่า missng แล้ว
# Out:
# Empty DataFrame
# Columns: [No., announce_date, Notified date, sex, age, Unit, nationality_x, province_of_isolation, risk_x, province_of_onset, district_of_onset, จังหวัด, 6 ภูมิภาค (ภูมิศาสตร์), geometry, txn_date, gender, age_number, age_range, nationality_y, job, risk_y, patient_type, province]
# Index: []
#
# [0 rows x 23 columns]

# %%
datagb = data_total2_drop.groupby('province_of_onset').size().reset_index(name='จำนวนผู้ติดเชื้อ')  
datagb
# Out:
#    province_of_onset  จำนวนผู้ติดเชื้อ
# 0             กระบี่              1494
# 1      กรุงเทพมหานคร            224513
# 2          กาญจนบุรี              2193
# 3          กาฬสินธุ์               330
# 4          กำแพงเพชร                45
# ..               ...               ...
# 69         เชียงใหม่              3940
# 70          เพชรบุรี              4605
# 71         เพชรบูรณ์                45
# 72               เลย               949
# 73        แม่ฮ่องสอน               112
#
# [74 rows x 2 columns]

# %%
datag = data_total2_drop.groupby('sex').size().reset_index(name='จำนวนผู้ติดเชื้อแบ่งตามเพศ')  
datag
# Out:
#     sex  จำนวนผู้ติดเชื้อแบ่งตามเพศ
# 0   ชาย                     1121847
# 1  หญิง                     1937917

# %% [markdown]
# ##แยกข้อมูลออกเป็นปี

# %% [markdown]
# ###ปี 2020

# %%
year0=list()
for each_row in data_project.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2020':
        year0.append(True)
    else:
        year0.append(False)

# %%
data_project[year0]
# Out:
#      announce_date Notified date   sex   age Unit  nationality  \
# 1826     14/5/2020     13/5/2020   ชาย  39.0   ปี     Thailand
# 1935     19/6/2020     18/6/2020   ชาย  24.0   ปี     Thailand
# 1936     19/6/2020     18/6/2020   ชาย  23.0   ปี     Thailand
# 1937     19/6/2020     18/6/2020   ชาย  27.0   ปี     Thailand
# 1938     19/6/2020     18/6/2020   ชาย  23.0   ปี     Thailand
# ...            ...           ...   ...   ...  ...          ...
# 2505    13/11/2020    12/11/2020  หญิง  52.0   ปี     Thailand
# 2506    13/11/2020    12/11/2020   ชาย  74.0   ปี  Switzerland
# 2507    13/11/2020    12/11/2020   ชาย  76.0   ปี  Switzerland
# 2508    13/11/2020    12/11/2020   ชาย  43.0   ปี       France
# 2509    13/11/2020    12/11/2020   ชาย  42.0   ปี       Kuwait
#
#      province_of_isolation                                           risk  \
# 1826             เชียงใหม่  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# ...

# %%
data2020 = data_project[year0]
data2020
# Out:
#      announce_date Notified date   sex   age Unit  nationality  \
# 1826     14/5/2020     13/5/2020   ชาย  39.0   ปี     Thailand
# 1935     19/6/2020     18/6/2020   ชาย  24.0   ปี     Thailand
# 1936     19/6/2020     18/6/2020   ชาย  23.0   ปี     Thailand
# 1937     19/6/2020     18/6/2020   ชาย  27.0   ปี     Thailand
# 1938     19/6/2020     18/6/2020   ชาย  23.0   ปี     Thailand
# ...            ...           ...   ...   ...  ...          ...
# 2505    13/11/2020    12/11/2020  หญิง  52.0   ปี     Thailand
# 2506    13/11/2020    12/11/2020   ชาย  74.0   ปี  Switzerland
# 2507    13/11/2020    12/11/2020   ชาย  76.0   ปี  Switzerland
# 2508    13/11/2020    12/11/2020   ชาย  43.0   ปี       France
# 2509    13/11/2020    12/11/2020   ชาย  42.0   ปี       Kuwait
#
#      province_of_isolation                                           risk  \
# 1826             เชียงใหม่  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# ...

# %%
ym_06=list() #ประกาศ ym_05 เป็น list ว่าง
for each_row in data2020.iterrows():  #เขียนลูปในตาราง data2021
    if each_row[1]['announce_date'].split('/')[1] == '6':
        ym_06.append(True)
    else:
        ym_06.append(False)

# %%
data2020[ym_06]
# Out:
#      announce_date Notified date  sex   age Unit nationality  \
# 1935     19/6/2020     18/6/2020  ชาย  24.0   ปี    Thailand
# 1936     19/6/2020     18/6/2020  ชาย  23.0   ปี    Thailand
# 1937     19/6/2020     18/6/2020  ชาย  27.0   ปี    Thailand
# 1938     19/6/2020     18/6/2020  ชาย  23.0   ปี    Thailand
# 1939     19/6/2020     18/6/2020  ชาย  26.0   ปี    Thailand
#
#      province_of_isolation              risk province_of_onset  \
# 1935         กรุงเทพมหานคร  State Quarantine     กรุงเทพมหานคร
# 1936         กรุงเทพมหานคร  State Quarantine     กรุงเทพมหานคร
# 1937         กรุงเทพมหานคร  State Quarantine     กรุงเทพมหานคร
# 1938         กรุงเทพมหานคร  State Quarantine     กรุงเทพมหานคร
# 1939         กรุงเทพมหานคร  State Quarantine     กรุงเทพมหานคร
#
#      district_of_onset  ... 5 ภูมิภาค (การท่องเที่ยว)           name  \
# 1935           ราชเทวี  ...                      กลาง  กรุงเทพมหานคร
# 1936           ราชเทวี  ...                      กลาง  กรุงเทพมหานคร
# ...

# %%
data2020m6 = data2020[ym_06]

# %%
data2020m6.to_csv('data2020m6.csv')

# %%
data2020m6.to_csv(os.path.join(path,'data2020m6.csv'))

# %% [markdown]
# ###ปี 2021

# %%
year1=list()
for each_row in data_project.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2021':
        year1.append(True)
    else:
        year1.append(False)

data_project[year1].head()
# Out:
#      announce_date Notified date   sex   age Unit nationality  \
# 7207     20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7208     20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7209     20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7210     20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7211     20/1/2021     19/1/2021  หญิง  18.0   ปี    Thailand
#
#      province_of_isolation                                         risk  \
# 7207                นครพนม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 7208                นครพนม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 7209                นครพนม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 7210                นครพนม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 7211             สมุทรสาคร                            Cluster สมุทรสาคร
#
#      province_of_onset district_of_onset  ... 5 ภูมิภาค (การท่องเที่ยว)  \
# 7207            นครพนม           ธาตุพนม  ...        ตะวันออกเฉียงเหนือ
# ...

# %%
data_project[year1]
# Out:
#         announce_date Notified date   sex   age Unit nationality  \
# 7207        20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7208        20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7209        20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7210        20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7211        20/1/2021     19/1/2021  หญิง  18.0   ปี    Thailand
# ...               ...           ...   ...   ...  ...         ...
# 3989830    23/12/2021    22/12/2021  หญิง  59.0   ปี  Indonesian
# 3989831    23/12/2021    22/12/2021  หญิง  59.0   ปี  Indonesian
# 3989832    23/12/2021    22/12/2021   ชาย  34.0   ปี    American
# 3989833    23/12/2021    22/12/2021   ชาย  34.0   ปี    American
# 3989834    23/12/2021    22/12/2021   ชาย  34.0   ปี    American
#
#         province_of_isolation                                         risk  \
# 7207                   นครพนม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
data2021 = data_project[year1]
data2021
# Out:
#         announce_date Notified date   sex   age Unit nationality  \
# 7207        20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7208        20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7209        20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7210        20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7211        20/1/2021     19/1/2021  หญิง  18.0   ปี    Thailand
# ...               ...           ...   ...   ...  ...         ...
# 3989830    23/12/2021    22/12/2021  หญิง  59.0   ปี  Indonesian
# 3989831    23/12/2021    22/12/2021  หญิง  59.0   ปี  Indonesian
# 3989832    23/12/2021    22/12/2021   ชาย  34.0   ปี    American
# 3989833    23/12/2021    22/12/2021   ชาย  34.0   ปี    American
# 3989834    23/12/2021    22/12/2021   ชาย  34.0   ปี    American
#
#         province_of_isolation                                         risk  \
# 7207                   นครพนม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
ym_11=list() #ประกาศ ym_15 เป็น list ว่าง
for each_row in data2021.iterrows():  #เขียนลูปในตาราง data2021
    if each_row[1]['announce_date'].split('/')[1] == '1':
        ym_11.append(True)
    else:
        ym_11.append(False)

# %%
data2021[ym_11]
# Out:
#       announce_date Notified date   sex   age Unit nationality  \
# 7207      20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7208      20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7209      20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7210      20/1/2021     19/1/2021  หญิง  51.0   ปี    Thailand
# 7211      20/1/2021     19/1/2021  หญิง  18.0   ปี    Thailand
# ...             ...           ...   ...   ...  ...         ...
# 10065     28/1/2021     27/1/2021   ชาย  33.0   ปี    Thailand
# 10066     28/1/2021     27/1/2021  หญิง  19.0   ปี       Burma
# 10067     28/1/2021     27/1/2021  หญิง  26.0   ปี       Burma
# 10068     28/1/2021     27/1/2021  หญิง  53.0   ปี    Thailand
# 10069     28/1/2021     27/1/2021  หญิง  39.0   ปี    Thailand
#
#       province_of_isolation                                         risk  \
# 7207                 นครพนม  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...

# %%
data2021m1 = data2021[ym_11]

# %%
data2021m1.to_csv('data2021m1.csv')

# %%
data2021m1.to_csv(os.path.join(path,'data2021m1.csv'))

# %% [markdown]
# ###ปี 2022

# %%
year2=list()
for each_row in data_project.iterrows():
    if each_row[1]['announce_date'].split('/')[2] == '2022':
        year2.append(True)
    else:
        year2.append(False)

data_project[year2].head()
# Out:
#         announce_date Notified date   sex   age Unit nationality  \
# 4011358      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011359      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011360      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011361      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011362      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
#
#         province_of_isolation   risk province_of_onset district_of_onset  ...  \
# 4011358                 ลำปาง  อื่นๆ             ลำปาง            แจ้ห่ม  ...
# 4011359                 ลำปาง  อื่นๆ             ลำปาง            แจ้ห่ม  ...
# 4011360                 ลำปาง  อื่นๆ             ลำปาง            แจ้ห่ม  ...
# 4011361                 ลำปาง  อื่นๆ             ลำปาง            แจ้ห่ม  ...
# 4011362                 ลำปาง  อื่นๆ             ลำปาง            แจ้ห่ม  ...
#
#         5 ภูมิภาค (การท่องเที่ยว)   name  \
# 4011358                     เหนือ  ลำปาง
# ...

# %%
data_project[year2]
# Out:
#         announce_date Notified date   sex   age Unit nationality  \
# 4011358      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011359      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011360      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011361      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011362      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# ...               ...           ...   ...   ...  ...         ...
# 5184282      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
# 5184283      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
# 5184284      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
# 5184285      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
# 5184286      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
#
#         province_of_isolation   risk province_of_onset district_of_onset  ...  \
# 4011358                 ลำปาง  อื่นๆ             ลำปาง            แจ้ห่ม  ...
# ...

# %%
data2022 = data_project[year2]

# %%
data2022
# Out:
#         announce_date Notified date   sex   age Unit nationality  \
# 4011358      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011359      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011360      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011361      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011362      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# ...               ...           ...   ...   ...  ...         ...
# 5184282      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
# 5184283      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
# 5184284      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
# 5184285      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
# 5184286      4/3/2022      3/3/2022   ชาย  67.0   ปี    Thailand
#
#         province_of_isolation   risk province_of_onset district_of_onset  ...  \
# 4011358                 ลำปาง  อื่นๆ             ลำปาง            แจ้ห่ม  ...
# ...

# %%
ym_21=list() #ประกาศ ym_26 เป็น list ว่าง
for each_row in data2022.iterrows():  #เขียนลูปในตาราง data2021
    if each_row[1]['announce_date'].split('/')[1] == '1':
        ym_21.append(True)
    else:
        ym_21.append(False)

# %%
data2022[ym_21]
# Out:
#         announce_date Notified date   sex   age Unit nationality  \
# 4011358      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011359      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011360      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011361      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# 4011362      4/1/2022      3/1/2022  หญิง  31.0   ปี    Thailand
# ...               ...           ...   ...   ...  ...         ...
# 4394404     28/1/2022     27/1/2022  หญิง  13.0   ปี    American
# 4394405     28/1/2022     27/1/2022  หญิง  13.0   ปี    American
# 4394406     28/1/2022     27/1/2022  หญิง  13.0   ปี    American
# 4394407     28/1/2022     27/1/2022  หญิง  13.0   ปี    American
# 4394408     28/1/2022     27/1/2022  หญิง  13.0   ปี    American
#
#         province_of_isolation                                     risk  \
# 4011358                 ลำปาง                                    อื่นๆ
# ...

# %%
data2022m1 = data2022[ym_21]

# %%
data2022m1.to_csv('data2022m1.csv')

# %%
data2022m1.to_csv(os.path.join(path,'data2022m1.csv'))
