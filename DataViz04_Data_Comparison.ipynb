# %% [markdown]
# <a href="https://colab.research.google.com/github/sskboonmee/data_viz_2022/blob/main/DataViz04_Data_Comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # เปรียบเทียบ ข้อมูล ด้วย coordinate plot

# %%
import pandas as pd

# %%
example_df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
example_df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
sample_data = example_df.groupby('Name').mean()

# %%
sample_data
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth
# Name
# Iris-setosa            5.006       3.418        1.464       0.244
# Iris-versicolor        5.936       2.770        4.260       1.326
# Iris-virginica         6.588       2.974        5.552       2.026

# %%
sample_data.iloc[0,:]
# Out:
# SepalLength    5.006
# SepalWidth     3.418
# PetalLength    1.464
# PetalWidth     0.244
# Name: Iris-setosa, dtype: float64

# %%
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^')

# %%
plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro-') #- คือเส้นเชื่อมโยง
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*-')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^-')

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^')

# %% [markdown]
# ## การใช้ plt.plot
#
# `plt.plot`(`พิกัดแกน X`,`พิกัดแกน Y`,` ลักษณะของ maker ` + `เส้นเชื่อม` )
# maker -> 'cML'

# %%
plt.plot([1],[2],'ro')

# %%
plt.plot([1,2],[2,4],'ro')

# %%
plt.plot([1,2],[2,4],'ro-.')

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro',label='Setosa')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*',label='Versicolor')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^',label='Virginica')
plt.legend()

# %%
example_df.iloc[:,:-1].columns.tolist()
# Out:
# ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth']

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro',label='Setosa')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*',label='Versicolor')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^',label='Virginica')
plt.legend()
plt.xticks([1,2,3,4], example_df.iloc[:,:-1].columns.tolist(), rotation='vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x7f6a079eb710>,
# ...
#  [Text(0, 0, 'SepalLength'),
#   Text(0, 0, 'SepalWidth'),
#   Text(0, 0, 'PetalLength'),
#   Text(0, 0, 'PetalWidth')])

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro',label='Setosa')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*',label='Versicolor')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^',label='Virginica')
plt.legend()
plt.xticks([1,2,3,4], example_df.iloc[:,:-1].columns.tolist(), rotation='vertical')
plt.title('Features comparison between 3 different Iris flowers');

# %%
plt.plot([1,1],[min(sample_data.iloc[:,0]),max(sample_data.iloc[:,0])],'c:')
plt.plot([2,2],[min(sample_data.iloc[:,1]),max(sample_data.iloc[:,1])],'c:')
plt.plot([3,3],[min(sample_data.iloc[:,2]),max(sample_data.iloc[:,2])],'c:')
plt.plot([4,4],[min(sample_data.iloc[:,3]),max(sample_data.iloc[:,3])],'c:')

plt.plot([1,2,3,4],sample_data.iloc[0,:],'ro',label='Setosa')
plt.plot([1,2,3,4],sample_data.iloc[1,:],'g*',label='Versicolor')
plt.plot([1,2,3,4],sample_data.iloc[2,:],'b^',label='Virginica')

plt.legend()
plt.xticks([1,2,3,4], example_df.iloc[:,:-1].columns.tolist(), rotation='vertical')
plt.title('Features comparison between 3 different Iris flowers')
plt.ylabel('size (cm)');

# %% [markdown]
# #HW วาดรูป ก้อนเมฆ และ ฝน

# %%
plt.plot([2,2.5,3,3.5,4],[8,6,6,6,8],'b-')  #ก้อนเมฆ
plt.plot([2,2.5,3,3.5,4],[8,10,8,10,8],'b-')   #ก้อนเมฆ
plt.plot([2.5,2.5,2.5],[5,4,3],'bo') #ฝน
plt.plot([3,3,3],[5,4,3],'bo')  #ฝน
plt.plot([3.5,3.5,3.5],[5,4,3],'bo')  #ฝน

# %% [markdown]
# #Bar chart

# %%
sample_data
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth
# Name
# Iris-setosa            5.006       3.418        1.464       0.244
# Iris-versicolor        5.936       2.770        4.260       1.326
# Iris-virginica         6.588       2.974        5.552       2.026

# %%
sample_data['PetalLength']
# Out:
# Name
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: PetalLength, dtype: float64

# %%
plt.bar([1,2,3],sample_data['PetalLength'])
plt.xticks([1,2,3], sample_data.reset_index()['Name'], rotation='vertical')
plt.title('Comparison between average petal length of 3 iris flowers')
plt.ylabel('size (cm)');

# %%
plt.bar([1,2,3],sample_data['PetalLength'])
plt.xticks([1,2,3], sample_data.reset_index()['Name'], rotation='vertical')
plt.title('Comparison between average petal length of 3 iris flowers')
plt.grid(True,axis='y')
plt.ylabel('size (cm)');

# %%
plt.bar([1,2,3],sample_data['PetalLength'],color=['r','g','b'])
plt.xticks([1,2,3], sample_data.reset_index()['Name'], rotation='vertical')
plt.title('Comparison between average petal length of 3 iris flowers')
plt.grid(True)
plt.ylabel('size (cm)');

# %% [markdown]
# ###เปรียบเทียบปริมาณมากกว่า 1 ปริมาณ object หลาย class

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
width = 0.2

plt.bar([1, 2],[sample_data['PetalLength'][1],sample_data['PetalWidth'][1]],width,color='g',label='versicolor') #ดอกที่ 2 versicolor
plt.bar([1-width, 2-width],[sample_data['PetalLength'][0],sample_data['PetalWidth'][0]],width,color='r',label='setosa') #ดอกที่ 1 setosa ขยับซ้าย
plt.bar([1+width, 2+width],[sample_data['PetalLength'][2],sample_data['PetalWidth'][2]],width,color='b',label='virginica') #ดอกที่ 1 setosa ขยับซ้าย

plt.xticks([1,2], ['Petal Length','Petal Width'])
plt.legend();

# %% [markdown]
# ###ปริมาณหลายอันมาซ้อนกัน

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
plt.bar([1,2,3],sample_data['PetalLength'],color='b',label='Petal Length')
plt.bar([1,2,3],sample_data['PetalWidth'],bottom=sample_data['PetalLength'],color='r',label='Petal Width')
plt.xticks([1,2,3], sample_data.reset_index()['Name'])
plt.grid(True,axis='y')
plt.legend();

# %% [markdown]
# ###Bar chart แบบตะแคงข้าง

# %%
plt.barh([1,2,3],sample_data['PetalLength'],color='b',label='Petal Length')
plt.barh([1,2,3],sample_data['PetalWidth'],left=sample_data['PetalLength'],color='r',label='Petal Width')
plt.yticks([1,2,3], sample_data.reset_index()['Name'])
plt.grid(True,axis='x')
plt.legend();

# %% [markdown]
# # HW7
# 1. plot bar chart เปรียบเทียบ sepal length, sepal width, petal length, petal width ของดอก iris ทั้ง 3 ชนิด
# 2. plot bar chart เพื่อเปรียบเทียบขนาโดยรวมของ iris ทั้ง 3 ชนิด โดยดูจาก sepal length, sepal width, petal length และ  petal width

# %% [markdown]
# #####ข้อ1

# %%
width = 0.2

plt.bar([1,2,3,4],[sample_data['PetalLength'][1],sample_data['PetalWidth'][1],sample_data['SepalLength'][1],sample_data['SepalWidth'][1]],width,color='g',label='versicolor') #ดอกที่ 2 versicolor
plt.bar([1-width,2-width,3-width,4-width],[sample_data['PetalLength'][0],sample_data['PetalWidth'][0],sample_data['SepalLength'][0],sample_data['SepalWidth'][0]],width,color='r',label='setosa') #ดอกที่ 1 setosa ขยับซ้าย
plt.bar([1+width,2+width,3+width,4+width],[sample_data['PetalLength'][2],sample_data['PetalWidth'][2],sample_data['SepalLength'][2],sample_data['SepalWidth'][2]],width,color='b',label='virginica') #ดอกที่ 1 verginica ขยับซ้าย

plt.xticks([1,2,3,4], ['Petal Length','Petal Width','Sepal Length','Sepall Width'])
plt.legend();

# %% [markdown]
# #####ข้อ 2

# %%
plt.bar([1,2,3],sample_data['PetalLength'],color='g',label='Petal Length')
plt.bar([1,2,3],sample_data['PetalWidth'],bottom=sample_data['PetalLength'],color='c',label='Petal Width')
plt.bar([1,2,3],sample_data['SepalLength'],bottom=sample_data['PetalWidth'] + sample_data['PetalLength'] ,color='b',label='Sepal Length')
plt.bar([1,2,3],sample_data['SepalWidth'],bottom=sample_data['SepalLength'] + sample_data['PetalWidth'] + sample_data['PetalLength'] ,color='k',label='Sepal Length')
plt.xticks([1,2,3], sample_data.reset_index()['Name'])
plt.grid(True,axis='y')
plt.legend();

# %% [markdown]
# #Histogram
# จะแสดงความถี่ของข้อมูล

# %%
np.random.seed(2022)

X= np.random.randint(1,101,10000)

# %%
X
# Out:
# array([93, 46, 50, ..., 64,  7, 46])

# %%
histout = plt.hist(X)

# %%
histout
# Out:
# (array([1020., 1033.,  963.,  988., 1018.,  990., 1010., 1012.,  992.,
#          974.]),
#  array([  1. ,  10.9,  20.8,  30.7,  40.6,  50.5,  60.4,  70.3,  80.2,
#          90.1, 100. ]),
#  <a list of 10 Patch objects>)

# %%
histout[0]
# Out:
# array([1020., 1033.,  963.,  988., 1018.,  990., 1010., 1012.,  992.,
#         974.])

# %%
histout[1]
# Out:
# array([  1. ,  10.9,  20.8,  30.7,  40.6,  50.5,  60.4,  70.3,  80.2,
#         90.1, 100. ])
